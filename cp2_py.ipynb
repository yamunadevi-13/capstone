# %% [markdown]
# <a href="https://colab.research.google.com/github/yamunadevi-13/capstone/blob/main/cp2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SpeechRecognition pydub
# !apt install ffmpeg
# !pip install opencv-python
# !pip install soundfile
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 33.2 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...

# %%
from google.colab import files
from pydub import AudioSegment
from IPython.display import Audio

# Upload your .m4a file
uploaded = files.upload()
audio_path = list(uploaded.keys())[0]

# Convert M4A to WAV
if audio_path.endswith(".m4a"):
    sound = AudioSegment.from_file(audio_path, format="m4a")
    wav_path = audio_path.replace(".m4a", ".wav")
    sound.export(wav_path, format="wav")
    audio_path = wav_path

# Listen to the converted audio
display(Audio(audio_path))
# Out:
#      <input type="file" id="files-ea3166c9-1651-4ca0-b18d-a847db7b2d24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea3166c9-1651-4ca0-b18d-a847db7b2d24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()

with sr.AudioFile(audio_path) as source:
    audio_data = recognizer.record(source)

    try:
        text = recognizer.recognize_google(audio_data)
        print("📝 Transcribed Text:", text)
    except sr.UnknownValueError:
        print("❌ Could not understand audio")
# Out:
# 📝 Transcribed Text: I am writing

# %%
from google.colab import files
uploaded = files.upload()  # Upload A–Z images
# Out:
#      <input type="file" id="files-58de6fcd-492f-41a7-90af-8fdee9998330" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58de6fcd-492f-41a7-90af-8fdee9998330">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

if text:
    for word in text.lower().split():
        print(f"\n🧩 Word: {word.upper()}")
        for letter in word:
            if letter.isalpha():
                letter_path = f"{letter}.jpg"  # Make sure you have a-z images named like 'a.jpg', 'b.jpg', etc.
                img = cv2.imread(letter_path)
                if img is not None:
                    img = cv2.resize(img, (300, 300))
                    print(f"🔤 Letter: {letter.upper()}")
                    cv2_imshow(img)
                else:
                    print(f"⚠️ Image not found for letter: {letter.upper()}")
else:
    print("⚠️ No transcription available.")
# Out:
# 🧩 Word: I
# 🔤 Letter: I
# <PIL.Image.Image image mode=RGB size=300x300>
# 🧩 Word: AM
# 🔤 Letter: A
# <PIL.Image.Image image mode=RGB size=300x300>
# 🔤 Letter: M
# <PIL.Image.Image image mode=RGB size=300x300>
# 🧩 Word: WRITING
# 🔤 Letter: W
# <PIL.Image.Image image mode=RGB size=300x300>
# 🔤 Letter: R
# <PIL.Image.Image image mode=RGB size=300x300>
# 🔤 Letter: I
# <PIL.Image.Image image mode=RGB size=300x300>
# 🔤 Letter: T
# <PIL.Image.Image image mode=RGB size=300x300>
# 🔤 Letter: I
# <PIL.Image.Image image mode=RGB size=300x300>
# 🔤 Letter: N
# <PIL.Image.Image image mode=RGB size=300x300>
# 🔤 Letter: G
# <PIL.Image.Image image mode=RGB size=300x300>
